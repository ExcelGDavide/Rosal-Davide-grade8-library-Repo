# %% [markdown]
# <a href="https://colab.research.google.com/github/ExcelGDavide/Rosal-Davide-grade8-library-Repo/blob/main/Rosal_Davide_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
url = "https://raw.githubusercontent.com/ExcelGDavide/Rosal-Davide-grade8-library-Repo/refs/heads/main/books.json"
response = requests.get(url)
books = response.json()
print(books)
#make sure the url is the raw file from the github
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
# !pip install firebase-admin

# %%
import requests
import json
"""
The 'students' variable is already loaded from the URL in a previous cell.
Therefore, we can directly use the 'students' variable.
"""
data = books
print("JSON file loaded")
ref = db.reference("books")
for books in data["books"]:
  ref.child(str(books["id"])).set(books)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
books_data = ref.get()

for key, book in books_data.items():
    print(f"Book ID: {key}")
    print(f"Title: {book['title']}")
    print(f"Author: {book['author']}")
    print(f"Details: {book['details']}")
    print()
# Out:
# Book ID: 2001
# Title: Introduction to Python
# Author: Juan Dela Cruz
# Details: {'available': 3, 'copies': 5}
#
# Book ID: 2002
# Title: Data Structures Basics
# Author: Maria Santos
# Details: {'available': 2, 'copies': 4}
#
# Book ID: 2003
# Title: Web Development Essentials
# Author: Carlos Reyes
# Details: {'available': 6, 'copies': 6}

# %%
books_data = ref.get()

for book in books_data.values():
    print(f"Title: {book['title']}")
# Out:
# Title: Introduction to Python
# Title: Data Structures Basics
# Title: Web Development Essentials

# %%
books_data = ref.get()

for book in books_data.values():
    title = book['title']
    available = book['details']['available']

    print(f"Title: {title}")
    print(f"Available Copies: {available}")
    print()
# Out:
# Title: Introduction to Python
# Available Copies: 3
#
# Title: Data Structures Basics
# Available Copies: 2
#
# Title: Web Development Essentials
# Available Copies: 6

# %%
books_data = ref.get()

total_books = len(books_data)
print(f"Total number of books in the library: {total_books}")
# Out:
# Total number of books in the library: 3
